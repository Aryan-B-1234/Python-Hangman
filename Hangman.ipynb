# %%
#Installation 

# !pip3 install ColabTurtle
import ColabTurtle
from ColabTurtle.Turtle import *
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7655 sha256=983a3f8853c0ef9d62c972cfdc3988593e718c91d3ff65d5e9d2ab7790c72be4
#   Stored in directory: /Users/aryanbakhtiarynia/Library/Caches/pip/wheels/a8/ab/ce/4aca5e858d2561104f45e6164390067231381836678b908064
# Successfully built ColabTurtle
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# @title Hangman
print('Welcome to Jerry\'s hangman')

t=ColabTurtle.Turtle
t.initializeTurtle()
t.is_pen_down=False
t.left(90)
t.forward(200)
t.left(90)
t.forward(300)
t.is_pen_down=True
t.left(180)
t.forward(400)
t.right(90)
t.forward(120)
t.right(90)
t.forward(50)

print('Whats your name?')
name=input()

print(f'Welcome {name}')

import random

word_list = ['Ethos', 'Parallelogram', 'Indict', 'Rhombus', 'Pythagorem', 'Artifact']


word = (random.choice(word_list)).lower()

guess_word=['']*len(word)
print(guess_word)
incorrectguesses=0
while incorrectguesses<6:
  print(' do you want to guess a letter or a word')
  answer=input()
  if answer=='word':
    print('this is a guess')
    guess_word1 = input (f"Enter word:\n")
    if guess_word1==word:
      print('Congrats')
      break
    else:
      incorrectguesses=incorrectguesses+1
      if incorrectguesses==1:
            t.right(90)
            t.forward(30)
            t.left(90)
            t.forward(60)
            t.left(90)
            t.forward(60)
            t.left(90)
            t.forward(60)
            t.left(90)
            t.forward(30)
            t.left(90)
            t.is_pen_down=False
            t.forward(60)
            t.is_pen_down=True
      if incorrectguesses==2:
            t.forward(120)
            t.left(180)
            t.forward(90)
      if incorrectguesses==3:
            t.left(120)
            t.forward(70)
            t.left(180)
            t.forward(70)
            t.left(60)
      if incorrectguesses==4:
            t.right(120)
            t.forward(70)
            t.right(180)
            t.forward(70)
            t.right(240)
      if incorrectguesses==5:
            t.left(20160)
            t.forward(90)
            t.right(40)
            t.forward(90)
            t.left(13500180)
            t.forward(90)
            t.right(240)
      if incorrectguesses==6:
            t.right(20160)
            t.forward(90)
            t.left(40)
            t.forward(90)
            t.right(13500180)
            t.forward(90)
            t.left(140)
      print ('you lost a chance')
  if answer=='letter':
    print('give me a letter')
    letter=input()

    if letter in word:
      for l in range(len(word)):
        if word [l] == letter:
          guess_word[l]= letter
      print(guess_word)
    if letter not in word:
      print ('you lost a chance')
      incorrectguesses=incorrectguesses+1
      if incorrectguesses==1:
            t.right(90)
            t.forward(30)
            t.left(90)
            t.forward(60)
            t.left(90)
            t.forward(60)
            t.left(90)
            t.forward(60)
            t.left(90)
            t.forward(30)
            t.left(90)
            t.is_pen_down=False
            t.forward(60)
            t.is_pen_down=True
      if incorrectguesses==2:
            t.forward(120)
            t.left(180)
            t.forward(90)
      if incorrectguesses==3:
            t.left(120)
            t.forward(70)
            t.left(180)
            t.forward(70)
            t.left(60)
      if incorrectguesses==4:
            t.right(120)
            t.forward(70)
            t.right(180)
            t.forward(70)
            t.right(240)
      if incorrectguesses==5:
            t.left(20160)
            t.forward(90)
            t.right(40)
            t.forward(90)
            t.left(13500180)
            t.forward(90)
            t.right(240)
      if incorrectguesses==6:
            t.right(20160)
            t.forward(90)
            t.left(40)
            t.forward(90)
            t.right(13500180)
            t.forward(90)
            t.left(140)
# Out:
# Welcome to Jerry's hangman
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...
